# %%
import pandas as pd
path = "../data/mimic-iv-clinical-database-demo-2.2/hosp/"

# %%
files = ["admissions", "patients", "labevents", "d_labitems", "prescriptions","pharmacy"]
dfs = {}

for name in files:
    dfs[name] = pd.read_csv(path + f"{name}.csv.gz")

admissions = dfs["admissions"]
patients = dfs["patients"]
labs = dfs["labevents"]
d_items = dfs["d_labitems"]
prescriptions = dfs["prescriptions"]
pharmacy = dfs["pharmacy"]

# %%
patient  = patients.iloc[[0],: ]
patient_id = int(patient.loc[0,"subject_id"])
patient_id
# Out:
# 10014729

# %%
patient_admissions = admissions[admissions["subject_id"]==patient_id]
patient_admissions
# Out:
#      subject_id   hadm_id            admittime            dischtime deathtime  \
# 51     10014729  23300884  2125-03-19 16:58:00  2125-03-28 13:37:00       NaN
# 258    10014729  28889419  2125-02-27 07:15:00  2125-03-06 14:25:00       NaN
#
#                   admission_type admit_provider_id  admission_location  \
# 51                      EW EMER.            P76K54      EMERGENCY ROOM
# 258  SURGICAL SAME DAY ADMISSION            P17BJ5  PHYSICIAN REFERRAL
#
#     discharge_location insurance language marital_status  \
# 51    HOME HEALTH CARE     Other  ENGLISH         SINGLE
# 258   HOME HEALTH CARE     Other  ENGLISH         SINGLE
#
#                        race            edregtime            edouttime  \
# 51   WHITE - OTHER EUROPEAN  2125-03-19 12:36:00  2125-03-19 18:45:00
# 258  WHITE - OTHER EUROPEAN                  NaN                  NaN
#
#      hospital_expire_flag
# 51                      0
# 258                     0

# %%
patient_labs = labs[labs["subject_id"]==patient_id]
patient_labs.head()
# Out:
#       labevent_id  subject_id     hadm_id  specimen_id  itemid  \
# 2125       187725    10014729  23300884.0     47191659   51009
# 5697       187248    10014729  28889419.0        22524   51237
# 5698       187249    10014729  28889419.0        22524   51274
# 5699       187251    10014729  28889419.0     19503308   51222
# 5700       187254    10014729  28889419.0     19503308   51250
#
#      order_provider_id            charttime            storetime value  \
# 2125               NaN  2125-03-25 10:00:00  2125-03-25 10:54:00  13.5
# 5697               NaN  2125-02-27 14:00:00  2125-02-27 14:16:00   1.5
# 5698               NaN  2125-02-27 14:00:00  2125-02-27 14:16:00  16.1
# 5699               NaN  2125-02-27 14:00:00  2125-02-27 14:22:00   8.6
# 5700               NaN  2125-02-27 14:00:00  2125-02-27 14:22:00    87
#
#       valuenum valueuom  ref_range_lower  ref_range_upper      flag priority  \
# 2125      13.5    ug/mL             10.0             20.0       NaN  ROUTINE
# ...

# %%
patient_labs["itemid"].nunique()
# Out:
# 107

# %%
patient_labs["itemid"].value_counts()
# Out:
# itemid
# 51221    23
# 51222    21
# 51265    21
# 51301    21
# 51279    21
#          ..
# 51444     1
# 51455     1
# 51051     1
# 51457     1
# 52391     1
# Name: count, Length: 107, dtype: int64

# %%
d_items[d_items["itemid"]==51221]
# Out:
#       itemid       label  fluid    category
# 1067   51221  Hematocrit  Blood  Hematology

# %%
named_labs = patient_labs.merge(d_items,on="itemid")
named_labs.head()
# Out:
#    labevent_id  subject_id     hadm_id  specimen_id  itemid order_provider_id  \
# 0       187725    10014729  23300884.0     47191659   51009               NaN
# 1       187248    10014729  28889419.0        22524   51237               NaN
# 2       187249    10014729  28889419.0        22524   51274               NaN
# 3       187251    10014729  28889419.0     19503308   51222               NaN
# 4       187254    10014729  28889419.0     19503308   51250               NaN
#
#              charttime            storetime value  valuenum valueuom  \
# 0  2125-03-25 10:00:00  2125-03-25 10:54:00  13.5      13.5    ug/mL
# 1  2125-02-27 14:00:00  2125-02-27 14:16:00   1.5       1.5      NaN
# 2  2125-02-27 14:00:00  2125-02-27 14:16:00  16.1      16.1      sec
# 3  2125-02-27 14:00:00  2125-02-27 14:22:00   8.6       8.6     g/dL
# 4  2125-02-27 14:00:00  2125-02-27 14:22:00    87      87.0       fL
#
#    ref_range_lower  ref_range_upper      flag priority comments       label  \
# ...

# %%
prescriptions.head()
# Out:
#    subject_id   hadm_id  pharmacy_id poe_id  poe_seq order_provider_id  \
# 0    10027602  28166872     27168639    NaN      NaN               NaN
# 1    10027602  28166872     40720238    NaN      NaN               NaN
# 2    10027602  28166872     62845687    NaN      NaN               NaN
# 3    10027602  28166872     24340150    NaN      NaN               NaN
# 4    10027602  28166872     14435820    NaN      NaN               NaN
#
#              starttime stoptime drug_type              drug  ...  gsn ndc  \
# 0  2201-10-30 12:00:00      NaN      MAIN  Fentanyl Citrate  ...  NaN NaN
# 1  2201-10-30 12:00:00      NaN      MAIN  Fentanyl Citrate  ...  NaN NaN
# 2  2201-10-31 12:00:00      NaN      MAIN         Lorazepam  ...  NaN NaN
# 3  2201-10-30 12:00:00      NaN      MAIN         Midazolam  ...  NaN NaN
# 4  2201-10-30 12:00:00      NaN      MAIN         Midazolam  ...  NaN NaN
#
#    prod_strength form_rx dose_val_rx dose_unit_rx form_val_disp  \
# ...

# %%
pharmacy.head()
# Out:
#    subject_id   hadm_id  pharmacy_id poe_id            starttime stoptime  \
# 0    10027602  28166872     24340150    NaN  2201-10-30 12:00:00      NaN
# 1    10027602  28166872     14435820    NaN  2201-10-30 12:00:00      NaN
# 2    10027602  28166872     40720238    NaN  2201-10-30 12:00:00      NaN
# 3    10027602  28166872     27168639    NaN  2201-10-30 12:00:00      NaN
# 4    10027602  28166872     62845687    NaN  2201-10-31 12:00:00      NaN
#
#          medication              proc_type                            status  \
# 0         Midazolam  Miscellaneous Charges  Inactive (Due to a change order)
# 1         Midazolam  Miscellaneous Charges  Inactive (Due to a change order)
# 2  Fentanyl Citrate  Miscellaneous Charges  Inactive (Due to a change order)
# 3  Fentanyl Citrate  Miscellaneous Charges  Inactive (Due to a change order)
# 4         Lorazepam  Miscellaneous Charges  Inactive (Due to a change order)
#
# ...
