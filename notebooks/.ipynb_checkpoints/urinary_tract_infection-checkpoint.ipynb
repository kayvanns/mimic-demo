# %%
import pandas as pd
import matplotlib.pyplot as plt
import cleaning
from datetime import timedelta
# %load_ext autoreload
# %autoreload 2

path = "../data/mimic-iv-clinical-database-demo-2.2/hosp/"
path2 = "../data/mimic-iv-clinical-database-demo-2.2/icu/"

# %%
## reading files and creating dataframes for tables
files = ["admissions", "patients", "labevents", "d_labitems", "prescriptions","pharmacy","transfers", "diagnoses_icd","d_icd_diagnoses"]
dfs = {}

for name in files:
    dfs[name] = pd.read_csv(path + f"{name}.csv.gz")

admissions = dfs["admissions"]
patients = dfs["patients"]
labs = dfs["labevents"]
d_labitems = dfs["d_labitems"]
prescriptions = dfs["prescriptions"]
pharmacy = dfs["pharmacy"]
transfers=dfs["transfers"]
diagnoses = dfs["diagnoses_icd"]
d_diagnoses = dfs["d_icd_diagnoses"]

files2 = ["icustays", "inputevents", "outputevents", "procedureevents","chartevents", "datetimeevents", "d_items"]
dfs2 = {}

for name in files2:
    dfs2[name] = pd.read_csv(path2 + f"{name}.csv.gz")
icustays = dfs2["icustays"]
inputevents = dfs2["inputevents"]
outputevents = dfs2["outputevents"]
procedureevents = dfs2["procedureevents"]
chartevents = dfs2["chartevents"]
datetimeevents = dfs2["datetimeevents"]
d_items = dfs2["d_items"]

# %%
test = cleaning.get_base("Urinary Tract Infection")
test.head()
# Out:
#     hadm_id  subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0  23473524    10002428      F          80         2155       2011 - 2013
# 1  25797028    10002428      F          80         2155       2011 - 2013
# 2  25177949    10032725      F          38         2143       2011 - 2013
# 3  22490490    10037928      F          78         2175       2011 - 2013
# 4  29802992    10037928      F          78         2175       2011 - 2013
#
#           dod            admittime            dischtime deathtime  ...  \
# 0         NaN  2156-05-11 14:49:00  2156-05-22 14:16:00       NaN  ...
# 1         NaN  2155-07-14 19:15:00  2155-07-15 18:37:00       NaN  ...
# 2  2143-03-30  2143-02-17 14:20:00  2143-03-16 17:15:00       NaN  ...
# 3         NaN  2177-07-14 16:55:00  2177-07-24 13:33:00       NaN  ...
# 4         NaN  2179-07-25 00:06:00  2179-07-28 15:54:00       NaN  ...
#
#                       race            edregtime            edouttime  \
# 0                    WHITE  2156-05-11 11:29:00  2156-05-11 16:53:00
# 1                    WHITE  2155-07-14 16:58:00  2155-07-14 20:04:00
# 2   BLACK/AFRICAN AMERICAN  2143-02-17 07:19:00  2143-02-17 15:18:00
# 3  HISPANIC/LATINO - CUBAN  2177-07-14 14:52:00  2177-07-14 20:38:00
# 4  HISPANIC/LATINO - CUBAN  2179-07-24 18:21:00  2179-07-25 01:17:00
#
#   hospital_expire_flag     stay_id  \
# 0                    0  35479615.0
# 1                    0         NaN
# 2                    0         NaN
# 3                    0  31552399.0
# 4                    0         NaN
#
#                                      first_careunit  \
# 0               Surgical Intensive Care Unit (SICU)
# 1                                               NaN
# 2                                               NaN
# 3  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4                                               NaN
#
#                                       last_careunit               intime  \
# 0                Medical Intensive Care Unit (MICU)  2156-05-11 14:49:34
# 1                                               NaN                  NaN
# 2                                               NaN                  NaN
# 3  Medical/Surgical Intensive Care Unit (MICU/SICU)  2177-07-14 20:38:00
# 4                                               NaN                  NaN
#
#                outtime        los
# 0  2156-05-22 14:16:46  10.977222
# 1                  NaN        NaN
# 2                  NaN        NaN
# 3  2177-07-15 16:08:36   0.812917
# 4                  NaN        NaN
#
# [5 rows x 27 columns]

# %%
test = cleaning.datetime(test)
test.head()
# Out:
#     hadm_id  subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0  23473524    10002428      F          80         2155       2011 - 2013
# 1  25797028    10002428      F          80         2155       2011 - 2013
# 2  25177949    10032725      F          38         2143       2011 - 2013
# 3  22490490    10037928      F          78         2175       2011 - 2013
# 4  29802992    10037928      F          78         2175       2011 - 2013
#
#           dod           admittime           dischtime deathtime  ...  \
# 0         NaN 2156-05-11 14:49:00 2156-05-22 14:16:00       NaN  ...
# 1         NaN 2155-07-14 19:15:00 2155-07-15 18:37:00       NaN  ...
# 2  2143-03-30 2143-02-17 14:20:00 2143-03-16 17:15:00       NaN  ...
# 3         NaN 2177-07-14 16:55:00 2177-07-24 13:33:00       NaN  ...
# 4         NaN 2179-07-25 00:06:00 2179-07-28 15:54:00       NaN  ...
#
#   hospital_expire_flag     stay_id  \
# 0                    0  35479615.0
# 1                    0         NaN
# 2                    0         NaN
# 3                    0  31552399.0
# 4                    0         NaN
#
#                                      first_careunit  \
# 0               Surgical Intensive Care Unit (SICU)
# 1                                               NaN
# 2                                               NaN
# 3  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4                                               NaN
#
#                                       last_careunit              intime  \
# 0                Medical Intensive Care Unit (MICU) 2156-05-11 14:49:34
# 1                                               NaN                 NaT
# 2                                               NaN                 NaT
# 3  Medical/Surgical Intensive Care Unit (MICU/SICU) 2177-07-14 20:38:00
# 4                                               NaN                 NaT
#
#               outtime        los       ICU_length  Hospital_length  \
# 0 2156-05-22 14:16:46  10.977222 10 days 23:27:12 10 days 23:27:00
# 1                 NaT        NaN              NaT  0 days 23:22:00
# 2                 NaT        NaN              NaT 27 days 02:55:00
# 3 2177-07-15 16:08:36   0.812917  0 days 19:30:36  9 days 20:38:00
# 4                 NaT        NaN              NaT  3 days 15:48:00
#
#            end_window
# 0 2156-05-11 18:49:34
# 1                 NaT
# 2                 NaT
# 3 2177-07-15 00:38:00
# 4                 NaT
#
# [5 rows x 30 columns]

# %%
d_items[d_items["label"].str.contains("heart rate", case=False, na=False)]
# Out:
#       itemid                    label     abbreviation      linksto  \
# 2054  220047   Heart Rate Alarm - Low   HR Alarm - Low  chartevents
# 2063  220046  Heart rate Alarm - High  HR Alarm - High  chartevents
# 2577  220045               Heart Rate               HR  chartevents
#
#                  category unitname param_type  lownormalvalue  highnormalvalue
# 2054               Alarms      bpm    Numeric             NaN              NaN
# 2063               Alarms      bpm    Numeric             NaN              NaN
# 2577  Routine Vital Signs      bpm    Numeric             NaN              NaN

# %%
test = cleaning.get_chartevents(test)

# %%
cleaning.get_vitals(test)
# Out:
#        hadm_id  subject_id gender  anchor_age  anchor_year anchor_year_group  \
# 0     23473524    10002428      F          80         2155       2011 - 2013
# 1     23473524    10002428      F          80         2155       2011 - 2013
# 2     23473524    10002428      F          80         2155       2011 - 2013
# 3     23473524    10002428      F          80         2155       2011 - 2013
# 4     23473524    10002428      F          80         2155       2011 - 2013
# ...        ...         ...    ...         ...          ...               ...
# 5681  28157142    10015931      M          87         2176       2014 - 2016
# 5682  28157142    10015931      M          87         2176       2014 - 2016
# 5683  28157142    10015931      M          87         2176       2014 - 2016
# 5684  28157142    10015931      M          87         2176       2014 - 2016
# 5685  28157142    10015931      M          87         2176       2014 - 2016
#
#              dod           admittime           dischtime deathtime  ...  \
# 0            NaN 2156-05-11 14:49:00 2156-05-22 14:16:00       NaN  ...
# 1            NaN 2156-05-11 14:49:00 2156-05-22 14:16:00       NaN  ...
# 2            NaN 2156-05-11 14:49:00 2156-05-22 14:16:00       NaN  ...
# 3            NaN 2156-05-11 14:49:00 2156-05-22 14:16:00       NaN  ...
# 4            NaN 2156-05-11 14:49:00 2156-05-22 14:16:00       NaN  ...
# ...          ...                 ...                 ...       ...  ...
# 5681  2177-03-29 2176-11-14 18:02:00 2176-11-27 13:30:00       NaN  ...
# 5682  2177-03-29 2176-11-14 18:02:00 2176-11-27 13:30:00       NaN  ...
# 5683  2177-03-29 2176-11-14 18:02:00 2176-11-27 13:30:00       NaN  ...
# 5684  2177-03-29 2176-11-14 18:02:00 2176-11-27 13:30:00       NaN  ...
# 5685  2177-03-29 2176-11-14 18:02:00 2176-11-27 13:30:00       NaN  ...
#
#               end_window caregiver_id           charttime           storetime  \
# 0    2156-05-11 18:49:34      27479.0 2156-05-11 16:00:00 2156-05-11 16:27:00
# 1    2156-05-11 18:49:34      27479.0 2156-05-11 16:00:00 2156-05-11 16:09:00
# 2    2156-05-11 18:49:34      27479.0 2156-05-11 16:00:00 2156-05-11 16:05:00
# 3    2156-05-11 18:49:34      27479.0 2156-05-11 16:00:00 2156-05-11 16:05:00
# 4    2156-05-11 18:49:34      27479.0 2156-05-11 16:00:00 2156-05-11 16:27:00
# ...                  ...          ...                 ...                 ...
# 5681 2176-11-19 18:24:52          NaN 2176-11-19 14:57:00 2176-11-19 15:02:00
# 5682 2176-11-19 18:24:52          NaN 2176-11-19 14:57:00 2176-11-19 15:01:00
# 5683 2176-11-19 18:24:52          NaN 2176-11-19 14:57:00 2176-11-19 15:02:00
# 5684 2176-11-19 18:24:52          NaN 2176-11-19 14:57:00 2176-11-19 15:02:00
# 5685 2176-11-19 18:24:52      30222.0 2176-11-19 16:26:05                 NaT
#
#         itemid                        value valuenum valueuom warning  \
# 0     224417.0                           25    25.00    cmH2O     0.0
# 1     224735.0                     Variable      NaN      NaN     0.0
# 2     224687.0                         8.29     8.29    L/min     0.0
# 3     224696.0                           18    18.00    cmH2O     0.0
# 4     224391.0                      Incisor      NaN      NaN     0.0
# ...        ...                          ...      ...      ...     ...
# 5681  226536.0                           89    89.00    mEq/L     1.0
# 5682  224828.0                            1     1.00    mEq/L     0.0
# 5683  226540.0                           38    38.00        %     0.0
# 5684  226534.0                          122   122.00    mEq/L     1.0
# 5685  220001.0  .Care Plan - Post-operative      NaN      NaN     NaN
#
#      max_heart_rate_max
# 0                  73.0
# 1                  73.0
# 2                  73.0
# 3                  73.0
# 4                  73.0
# ...                 ...
# 5681              115.0
# 5682              115.0
# 5683              115.0
# 5684              115.0
# 5685              115.0
#
# [5686 rows x 39 columns]
